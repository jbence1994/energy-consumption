# %%
from pyspark.sql import Window
from pyspark.sql.functions import col, lead

# %%
silver_data_frame = spark.read.table("energy_consumption.bronze")

# %%
silver_data_frame = silver_data_frame.withColumn(
    colName="daily_kwh",
    col=lead("kwh").over(Window.orderBy("year", "month", "day")) - col("kwh"),
)

# %%
silver_data_frame = silver_data_frame.dropna()

# %%
(silver_data_frame.write.mode("overwrite").saveAsTable("energy_consumption.silver"))
