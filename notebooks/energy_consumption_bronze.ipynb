# %%
bronze_data_frame = (
    spark.read.option("header", "true")
    .option("inferSchema", "true")
    .csv("/Volumes/workspace/energy_consumption/source/data.csv")
)

# %%
(bronze_data_frame.write.mode("overwrite").saveAsTable("energy_consumption.bronze"))
